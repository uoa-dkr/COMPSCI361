# %% [markdown]
# # Association rules

# %% [markdown]
# ## Apriori

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori


data = pd.read_csv('data/supermarket.csv', names = range(49))
data.fillna('', inplace=True)
dataset = data.values
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.drop(columns = '', inplace = True)
frequent_itemsets = apriori(df, min_support=0.25, use_colnames=True)

frequent_itemsets
# Out:
#       support                                           itemsets
# 0    0.604063                                     (baking needs)
# 1    0.375837                                             (beef)
# 2    0.563000                                         (biscuits)
# 3    0.719689                                   (bread and cake)
# 4    0.402421                                   (breakfast food)
# ..        ...                                                ...
# 242  0.271234  (baking needs, vegetables, bread and cake, fruit)
# 243  0.252648  (milk-cream, vegetables, bread and cake, bakin...
# 244  0.262805      (biscuits, vegetables, bread and cake, fruit)
# 245  0.268424  (vegetables, bread and cake, frozen foods, fruit)
# 246  0.283337    (milk-cream, vegetables, bread and cake, fruit)
#
# [247 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules

rule = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.8)
rule
# Out:
#                                    antecedents       consequents  \
# 0                                  (margarine)  (bread and cake)
# 1                               (total = high)  (bread and cake)
# 2                     (baking needs, biscuits)  (bread and cake)
# 3                 (baking needs, frozen foods)  (bread and cake)
# 4                        (baking needs, fruit)  (bread and cake)
# 5                    (baking needs, margarine)  (bread and cake)
# 6                   (milk-cream, baking needs)  (bread and cake)
# 7            (baking needs, party snack foods)  (bread and cake)
# 8            (baking needs, sauces-gravy-pkle)  (bread and cake)
# 9            (baking needs, tissues-paper prd)  (bread and cake)
# 10                  (baking needs, vegetables)  (bread and cake)
# 11                    (biscuits, frozen foods)  (bread and cake)
# 12                           (biscuits, fruit)  (bread and cake)
# 13               (biscuits, juice-sat-cord-ms)  (bread and cake)
# 14                       (biscuits, margarine)  (bread and cake)
# 15                      (milk-cream, biscuits)  (bread and cake)
# 16               (biscuits, party snack foods)  (bread and cake)
# 17               (biscuits, tissues-paper prd)  (bread and cake)
# 18                      (biscuits, vegetables)  (bread and cake)
# 19                       (frozen foods, fruit)  (bread and cake)
# 20                   (frozen foods, margarine)  (bread and cake)
# 21                  (milk-cream, frozen foods)  (bread and cake)
# 22           (frozen foods, party snack foods)  (bread and cake)
# 23           (sauces-gravy-pkle, frozen foods)  (bread and cake)
# 24           (frozen foods, tissues-paper prd)  (bread and cake)
# 25                  (vegetables, frozen foods)  (bread and cake)
# 26                  (juice-sat-cord-ms, fruit)  (bread and cake)
# 27                          (margarine, fruit)  (bread and cake)
# 28                         (milk-cream, fruit)  (bread and cake)
# 29                  (party snack foods, fruit)  (bread and cake)
# 30                  (sauces-gravy-pkle, fruit)  (bread and cake)
# 31                  (tissues-paper prd, fruit)  (bread and cake)
# 32                         (vegetables, fruit)  (bread and cake)
# 33             (milk-cream, juice-sat-cord-ms)  (bread and cake)
# 34                     (milk-cream, margarine)  (bread and cake)
# 35                     (vegetables, margarine)  (bread and cake)
# 36             (milk-cream, party snack foods)  (bread and cake)
# 37             (milk-cream, sauces-gravy-pkle)  (bread and cake)
# 38             (milk-cream, tissues-paper prd)  (bread and cake)
# 39                    (milk-cream, vegetables)  (bread and cake)
# 40             (vegetables, party snack foods)  (bread and cake)
# 41             (vegetables, sauces-gravy-pkle)  (bread and cake)
# 42             (vegetables, tissues-paper prd)  (bread and cake)
# 43           (milk-cream, baking needs, fruit)  (bread and cake)
# 49            0.334558            0.640156  0.268424    0.802326  1.253329
# 50            0.313594            0.719689  0.268424    0.855961  1.189349
# 51            0.334558            0.639939  0.268424    0.802326  1.253752
# 52            0.339529            0.719689  0.283337    0.834500  1.159529
#
#     leverage  conviction
# 0   0.039843    1.403396
# 1   0.044228    1.769333
# 2   0.040300    1.605419
# 3   0.035524    1.469632
# 4   0.042488    1.585093
# 5   0.037630    1.606662
# 6   0.044857    1.634720
# 7   0.033040    1.553899
# 8   0.027740    1.430716
# 9   0.034997    1.580393
# 10  0.039621    1.505032
# 11  0.044816    1.691211
# 12  0.047316    1.739634
# 13  0.032254    1.527349
# 14  0.038147    1.729358
# 15  0.046101    1.756418
# 16  0.034635    1.560334
# 17  0.035291    1.669230
# 18  0.047000    1.785087
# 19  0.045096    1.666643
# 20  0.031804    1.521831
# 21  0.043624    1.651123
# 22  0.031219    1.483118
# 23  0.029528    1.482777
# 24  0.033687    1.585971
# 25  0.041830    1.579478
# 26  0.032998    1.483166
# 27  0.041953    1.819066
# 28  0.046958    1.613769
# 29  0.037877    1.646699
# 30  0.033210    1.582060
# 31  0.036578    1.626843
# 32  0.043797    1.487132
# 33  0.033687    1.514421
# 34  0.039810    1.736808
# 35  0.038871    1.678694
# 36  0.035868    1.623908
# 37  0.031516    1.538091
# 38  0.040067    1.775695
# 39  0.043361    1.546676
# 40  0.032636    1.527990
# 41  0.031711    1.505948
# 42  0.036958    1.642877
# 43  0.038605    1.875612
# 44  0.039633    1.783690
# 45  0.054924    1.822442
# 46  0.036134    1.749745
# 47  0.057076    1.974497
# 48  0.044426    2.093388
# 49  0.054255    1.820389
# 50  0.042734    1.946084
# 51  0.054328    1.821483
# 52  0.038982    1.693727

# %% [markdown]
# ## FP-tree

# %%
from mlxtend.frequent_patterns import fpgrowth

data = pd.read_csv('data/supermarket.csv', names = range(49))
data.fillna('', inplace=True)
dataset = data.values
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.drop(columns = '', inplace = True)
frequent_itemsets = fpgrowth(df, min_support=0.25, use_colnames=True)

frequent_itemsets
# Out:
#       support                          itemsets
# 0    0.719689                  (bread and cake)
# 1    0.640156                           (fruit)
# 2    0.639939                      (vegetables)
# 3    0.635185                      (milk-cream)
# 4    0.604063                    (baking needs)
# ..        ...                               ...
# 242  0.258699       (baking needs, soft drinks)
# 243  0.257834           (biscuits, soft drinks)
# 244  0.273395       (soft drinks, frozen foods)
# 245  0.264102         (vegetables, soft drinks)
# 246  0.251135  (soft drinks, party snack foods)
#
# [247 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules

rule = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.8)
rule
# Out:
#                                    antecedents       consequents  \
# 0                          (vegetables, fruit)  (bread and cake)
# 1                          (milk-cream, fruit)  (bread and cake)
# 2                     (milk-cream, vegetables)  (bread and cake)
# 3              (milk-cream, vegetables, fruit)  (bread and cake)
# 4                   (baking needs, vegetables)  (bread and cake)
# 5                   (milk-cream, baking needs)  (bread and cake)
# 6       (milk-cream, vegetables, baking needs)  (bread and cake)
# 7                        (baking needs, fruit)  (bread and cake)
# 8            (baking needs, vegetables, fruit)  (bread and cake)
# 9        (baking needs, bread and cake, fruit)      (vegetables)
# 10           (milk-cream, baking needs, fruit)  (bread and cake)
# 11                  (vegetables, frozen foods)  (bread and cake)
# 12                       (frozen foods, fruit)  (bread and cake)
# 13  (vegetables, bread and cake, frozen foods)           (fruit)
# 14           (vegetables, frozen foods, fruit)  (bread and cake)
# 15       (bread and cake, frozen foods, fruit)      (vegetables)
# 16                (baking needs, frozen foods)  (bread and cake)
# 17                  (milk-cream, frozen foods)  (bread and cake)
# 18                           (biscuits, fruit)  (bread and cake)
# 19                    (biscuits, frozen foods)  (bread and cake)
# 20                      (milk-cream, biscuits)  (bread and cake)
# 21                    (baking needs, biscuits)  (bread and cake)
# 22                      (biscuits, vegetables)  (bread and cake)
# 23      (biscuits, vegetables, bread and cake)           (fruit)
# 24               (biscuits, vegetables, fruit)  (bread and cake)
# 25                  (juice-sat-cord-ms, fruit)  (bread and cake)
# 26             (milk-cream, juice-sat-cord-ms)  (bread and cake)
# 27               (biscuits, juice-sat-cord-ms)  (bread and cake)
# 28               (biscuits, party snack foods)  (bread and cake)
# 29                  (party snack foods, fruit)  (bread and cake)
# 30           (frozen foods, party snack foods)  (bread and cake)
# 31             (vegetables, party snack foods)  (bread and cake)
# 32             (milk-cream, party snack foods)  (bread and cake)
# 33           (baking needs, party snack foods)  (bread and cake)
# 34                                 (margarine)  (bread and cake)
# 35                   (baking needs, margarine)  (bread and cake)
# 36                     (vegetables, margarine)  (bread and cake)
# 37                     (milk-cream, margarine)  (bread and cake)
# 38                          (margarine, fruit)  (bread and cake)
# 39                   (frozen foods, margarine)  (bread and cake)
# 40                       (biscuits, margarine)  (bread and cake)
# 41           (baking needs, tissues-paper prd)  (bread and cake)
# 42                  (tissues-paper prd, fruit)  (bread and cake)
# 43             (vegetables, tissues-paper prd)  (bread and cake)
# 44             (milk-cream, tissues-paper prd)  (bread and cake)
# 45           (frozen foods, tissues-paper prd)  (bread and cake)
# 46               (biscuits, tissues-paper prd)  (bread and cake)
# 47             (vegetables, sauces-gravy-pkle)  (bread and cake)
# 48           (baking needs, sauces-gravy-pkle)  (bread and cake)
# 49           (sauces-gravy-pkle, frozen foods)  (bread and cake)
# 50                  (sauces-gravy-pkle, fruit)  (bread and cake)
# 51             (milk-cream, sauces-gravy-pkle)  (bread and cake)
# 52                              (total = high)  (bread and cake)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.476983            0.719689  0.387076    0.811509  1.127583
# 1             0.440458            0.719689  0.363951    0.826300  1.148136
# 2             0.437649            0.719689  0.358332    0.818765  1.137666
# 3             0.339529            0.719689  0.283337    0.834500  1.159529
# 4             0.421223            0.719689  0.342771    0.813751  1.130698
# 5             0.412146            0.719689  0.341474    0.828526  1.151229
# 6             0.300843            0.719689  0.252648    0.839799  1.166892
# 7             0.410633            0.719689  0.338016    0.823158  1.143769
# 8             0.321807            0.719689  0.271234    0.842848  1.171128
# 9             0.338016            0.639939  0.271234    0.802430  1.253915
# 10            0.295008            0.719689  0.250919    0.850549  1.181830
# 11            0.406743            0.719689  0.334558    0.822529  1.142896
# 12            0.402204            0.719689  0.334558    0.831811  1.155792
# 13            0.334558            0.640156  0.268424    0.802326  1.253329
# 14            0.313594            0.719689  0.268424    0.855961  1.189349
# 15            0.334558            0.639939  0.268424    0.802326  1.253752
# 16            0.396585            0.719689  0.320942    0.809264  1.124464
# 17            0.394640            0.719689  0.327642    0.830230  1.153596
# 18            0.397018            0.719689  0.333045    0.838868  1.165598
# 19            0.391182            0.719689  0.326345    0.834254  1.159187
# 20            0.381889            0.719689  0.320942    0.840407  1.167737
